# %%
import cv2
import sys
import numpy as np

def nothing(x):
    pass

# Load in image
image = cv2.imread('zoomed.jpg')

# Create a window
cv2.namedWindow('image')

# create trackbars for color change
cv2.createTrackbar('HMin','image',0,179,nothing) # Hue is from 0-179 for Opencv
cv2.createTrackbar('SMin','image',0,255,nothing)
cv2.createTrackbar('VMin','image',0,255,nothing)
cv2.createTrackbar('HMax','image',0,179,nothing)
cv2.createTrackbar('SMax','image',0,255,nothing)
cv2.createTrackbar('VMax','image',0,255,nothing)

# Set default value for MAX HSV trackbars.
cv2.setTrackbarPos('HMax', 'image', 179)
cv2.setTrackbarPos('SMax', 'image', 255)
cv2.setTrackbarPos('VMax', 'image', 255)

# Initialize to check if HSV min/max value changes
hMin = sMin = vMin = hMax = sMax = vMax = 0
phMin = psMin = pvMin = phMax = psMax = pvMax = 0

output = image
wait_time = 33

while(1):

    # get current positions of all trackbars
    hMin = cv2.getTrackbarPos('HMin','image')
    sMin = cv2.getTrackbarPos('SMin','image')
    vMin = cv2.getTrackbarPos('VMin','image')

    hMax = cv2.getTrackbarPos('HMax','image')
    sMax = cv2.getTrackbarPos('SMax','image')
    vMax = cv2.getTrackbarPos('VMax','image')

    # Set minimum and max HSV values to display
    lower = np.array([hMin, sMin, vMin])
    upper = np.array([hMax, sMax, vMax])

    # Create HSV Image and threshold into a range.
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    mask = cv2.inRange(hsv, lower, upper)
    output = cv2.bitwise_and(image,image, mask= mask)

    # Print if there is a change in HSV value
    if( (phMin != hMin) | (psMin != sMin) | (pvMin != vMin) | (phMax != hMax) | (psMax != sMax) | (pvMax != vMax) ):
        print("(hMin = %d , sMin = %d, vMin = %d), (hMax = %d , sMax = %d, vMax = %d)" % (hMin , sMin , vMin, hMax, sMax , vMax))
        phMin = hMin
        psMin = sMin
        pvMin = vMin
        phMax = hMax
        psMax = sMax
        pvMax = vMax

    # Display output image
    cv2.imshow('image',output)

    # Wait longer to prevent freeze for videos.
    if cv2.waitKey(wait_time) & 0xFF == ord('q'):
        break

cv2.destroyAllWindows()
# Out:
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 4 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 12 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 16 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 17 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 18 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 20 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 21 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 22 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 24 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 27 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 31 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 32 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 33 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 35 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 7, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 15, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 17, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 19, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 23, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 26, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 29, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 30, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 33, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 34, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 35, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 36, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 38, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 39, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 42, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 43, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 8), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 13), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 15), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 16), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 19), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 25), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 27), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 28), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 30), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 33), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 34), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 38), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 44), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 48), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 50), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 52), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 55), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 57), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 58), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 60), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 64), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 65), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 244, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 214, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 207, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 198, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 192, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 179, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 174, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 173, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 166, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 138, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 134, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 133, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 145, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 189, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 250, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 246)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 154)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 112)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 103)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 88)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 72)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 61)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 60)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 65)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 77)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 94)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 103)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 112)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 115)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 116)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 120)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 129)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 140)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 148)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 149)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 151)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 161)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 164)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 145)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 122)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 114)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 108)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 103)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 97)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 96)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 116)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 128)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 130)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 131)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 133)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 141)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 146)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 152)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 159)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 167)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 170)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 177)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 180)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 191)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 196)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 211)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 224)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 227)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 232)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 239)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 243)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 252)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 177 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 148 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 138 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 135 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 132 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 131 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 129 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 127 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 123 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 121 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 119 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 118 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 117 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 115 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 114 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 113 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 111 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 109 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 108 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 109 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 111 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 123 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 134 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 138 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 140 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 145 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 149 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 151 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 152 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 153 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 155 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 159 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 162 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 163 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 164 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 166 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 172 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 173 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 176 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 178 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 176 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 171 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 164 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 160 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 157 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 156 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 154 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 150 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 146 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 145 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 144 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 143 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 142 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 66), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 62), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 60), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 59), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 58), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 57), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 55), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 54), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 53), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 51), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 50), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 48), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 46), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 45), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 44), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 43, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 37, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 35, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 34, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 33, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 32, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 34, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 35, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 37, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 41, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 43, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 46, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 49, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 50, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 51, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 54, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 56, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 57, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 58, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 56, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 55, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 51, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 50, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 49, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 48, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 47, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 46, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 45, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 46, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 38, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 35, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 37, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 38, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 39, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 40, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 41, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 42, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 43, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 45, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 46, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 47, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 48, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 49, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 50, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 51, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 48, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 42, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 41, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 40, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 39, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 41, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 42, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 43, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 45, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 46, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 47, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 48, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 49, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 48, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 47, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 48, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 49, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 47, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 44, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 43, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 42, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 40, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 39, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 38, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 39, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 40, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 42, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 43, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 45, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 46, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 47, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 48, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 49, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 50, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 51, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 176 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 172 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 168 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 166 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 165 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 162 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 161 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 160 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 157 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 155 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 152 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 150 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 148 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 145 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 138 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 137 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 136 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 134 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 133 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 128 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 127 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 123 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 118 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 112 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 106 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 102 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 98 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 94 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 91 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 87 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 85 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 82 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 80 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 79 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 78 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 77 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 78 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 79 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 80 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 81 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 80 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 79 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 78 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 77 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 76 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 52, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 103, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 88, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 83, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 79, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 77, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 75, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 70, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 64, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 58, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 53, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 45, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 38, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 32, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 27, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 19, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 9, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 0, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 51, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 43, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 37, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 36, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 35, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 33, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 31, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 30, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 29, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 30, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 31, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 32, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 33, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 34, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 35, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 36, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 37, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 40, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 43, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 42, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 40, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 42 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 43 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 44 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 45 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 46 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 47 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 48 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 50 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 51 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 53 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 54 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 55 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 57 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 59 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 63 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 65 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 66 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 67 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 72 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 76 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 77 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 82 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 83 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 81 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 79 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 76 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 73 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 72 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 71 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 69 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 66 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 65 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 64 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 63 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 59 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 57 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 55 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 51 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 50 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 49 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 47 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 45 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 43 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 42 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 38 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 37 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 36 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 35 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 34 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 33 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 32 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 31 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 30 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 29 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 28 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 26 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 25 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 24 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 23 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 22 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 21 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 20 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 18 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 17 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 15 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 14 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 12 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 11 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 10 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 9 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 10 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 11 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 12 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 14 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 15 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 16 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 17 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 18 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 19 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 19 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 246, vMax = 255)
# (hMin = 19 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 239, vMax = 255)
# (hMin = 19 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 238, vMax = 255)
# (hMin = 19 , sMin = 41, vMin = 43), (hMax = 75 , sMax = 233, vMax = 255)
# (hMin = 19 , sMin = 41, vMin = 43), (hMax = 75 , sMax =